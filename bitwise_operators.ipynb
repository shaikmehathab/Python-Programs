# %%
#BITWISE OPERATORS
a=20
b=30
print("a&b:",a&b)
print("a|b:",a|b)
print("a^b:",a^b)
print("~a:",~a)
print("a<<1:",a<<1)
print("a>>1:",a>>1)
# Out:
# a&b: 20
# a|b: 30
# a^b: 10
# ~a: -21
# a<<1: 40
# a>>1: 10
