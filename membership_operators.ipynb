# %%
#MEMBERSHIP OPERATORS
test="python progrsmming"
print ("'python'in test:",'python'in test)
print ("'java'in test:",'java'in test)
print("'python'not in test:",'python'not in test)
print("'java'not in test:",'java'not in test)
# Out:
# 'python'in test: True
# 'java'in test: False
# 'python'not in test: False
# 'java'not in test: True
