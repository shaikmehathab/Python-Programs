# %%
# compound intrest calculatre
p=float(input("enter principle:"))
r=float(input("enter rate:"))
t=float(input("enter time:"))
a=p*(1+r/100)**t
ci=a-p
print(ci)
print(a)
# Out:
# enter principle: 10
# enter rate: 20
# enter time: 30
# 2363.7631379976956
# 2373.7631379976956
