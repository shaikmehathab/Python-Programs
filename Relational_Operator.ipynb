# %%
#RELATIONAL OPERATOR
a=10
b=20
print("a==b:",a==b)
print("a!=b:",a!=b)
print("a>b:",a>b)
print("a<b:",a<b)
print("a>=b:",a>=b)
print("a<=b:",a<=b)
# Out:
# a==b: False
# a!=b: True
# a>b: False
# a<b: True
# a>=b: False
# a<=b: True
